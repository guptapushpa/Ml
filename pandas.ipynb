# %%
import pandas as pd
mdf=pd.read_csv('//content/Movie-Data.csv')
mdf
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df=pd.read_csv('/content/Movie-Data.csv',index_col='Title')
df
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
mdf.info
# Out:
# <bound method DataFrame.info of      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
mdf.shape
# Out:
# (1000, 12)

# %%
mdf.head(10)
# Out:
#    Rank                    Title                       Genre  \
# 0     1  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1     2               Prometheus    Adventure,Mystery,Sci-Fi
# 2     3                    Split             Horror,Thriller
# 3     4                     Sing     Animation,Comedy,Family
# 4     5            Suicide Squad    Action,Adventure,Fantasy
# 5     6           The Great Wall    Action,Adventure,Fantasy
# 6     7               La La Land          Comedy,Drama,Music
# 7     8                 Mindhorn                      Comedy
# 8     9       The Lost City of Z  Action,Adventure,Biography
# 9    10               Passengers     Adventure,Drama,Romance
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
mdf.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
df.tail
# Out:
# <bound method NDFrame.tail of                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
mdf.isnull()
# Out:
#       Rank  Title  Genre  Description  Director  Actors   Year  \
# 0    False  False  False        False     False   False  False
# 1    False  False  False        False     False   False  False
# 2    False  False  False        False     False   False  False
# 3    False  False  False        False     False   False  False
# 4    False  False  False        False     False   False  False
# ..     ...    ...    ...          ...       ...     ...    ...
# 995  False  False  False        False     False   False  False
# 996  False  False  False        False     False   False  False
# 997  False  False  False        False     False   False  False
# 998  False  False  False        False     False   False  False
# 999  False  False  False        False     False   False  False
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 0                False   False  False               False      False
# 1                False   False  False               False      False
# ...

# %%
mdf.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
#can you detete null value
df2=mdf.dropna()

# %%
df2.shape
# Out:
# (838, 12)

# %%
df2.isnull().sum()
# Out:
# Rank                  0
# Title                 0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    0
# Metascore             0
# dtype: int64

# %%
#df2=mdf.dropna(inplace=True) delete to all data null
#df2.shape

# %%
mdf['Revenue (Millions)']
# Out:
# 0      333.13
# 1      126.46
# 2      138.12
# 3      270.32
# 4      325.02
#         ...
# 995       NaN
# 996     17.54
# 997     58.01
# 998       NaN
# 999     19.64
# Name: Revenue (Millions), Length: 1000, dtype: float64

# %%
mdf.describe
# Out:
# <bound method NDFrame.describe of      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
r=mdf['Revenue (Millions)']

# %%
r
# Out:
# 0      333.13
# 1      126.46
# 2      138.12
# 3      270.32
# 4      325.02
#         ...
# 995       NaN
# 996     17.54
# 997     58.01
# 998       NaN
# 999     19.64
# Name: Revenue (Millions), Length: 1000, dtype: float64

# %%
type(r)
# Out:
# pandas.core.series.Series

# %%
r.mean()
# Out:
# 82.95637614678898

# %%
r2=mdf[['Revenue (Millions)']]

# %%
r2
# Out:
#      Revenue (Millions)
# 0                333.13
# 1                126.46
# 2                138.12
# 3                270.32
# 4                325.02
# ..                  ...
# 995                 NaN
# 996               17.54
# 997               58.01
# 998                 NaN
# 999               19.64
#
# [1000 rows x 1 columns]

# %%
type(r2)
# Out:
# pandas.core.frame.DataFrame

# %%
rmean=r.mean()
rmean
# Out:
# 82.95637614678898

# %%
r.fillna(rmean,inplace=True)
r.shape
# Out:
# (1000,)

# %%
r.isnull().sum()
# Out:
# 0

# %%
mdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  1000 non-null   float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
m=mdf['Metascore']
m
# Out:
# 0      76.0
# 1      65.0
# 2      62.0
# 3      59.0
# 4      40.0
#        ...
# 995    45.0
# 996    46.0
# 997    50.0
# 998    22.0
# 999    11.0
# Name: Metascore, Length: 1000, dtype: float64

# %%
type(m)
# Out:
# pandas.core.series.Series

# %%
mmean=r.mean()
mmean
# Out:
# 82.95637614678898

# %%
m.isnull().sum()
# Out:
# 64

# %%
m.fillna(mmean,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-60a9e6e8decb> in <module>
# ----> 1 m.fillna(mmean,inplace=True)
#       2
#
# NameError: name 'm' is not defined

# %%
m.shape
# Out:
# (1000,)

# %%
m.isnull().sum()
# Out:
# 0

# %%
mdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
mdf.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
import pandas as pd

# %%
mdf=pd.read_csv('/content/Movie-Data.csv', index_col='Title')
mdf
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
#columns wise filter
subset=mdf.loc['Prometheus']
subset
# Out:
# Rank                                                                  2
# Genre                                          Adventure,Mystery,Sci-Fi
# Description           Following clues to the origin of mankind, a te...
# Director                                                   Ridley Scott
# Actors                Noomi Rapace, Logan Marshall-Green, Michael Fa...
# Year                                                               2012
# Runtime (Minutes)                                                   124
# Rating                                                              7.0
# Votes                                                            485820
# Revenue (Millions)                                               126.46
# Metascore                                                          65.0
# Name: Prometheus, dtype: object

# %%
subset=mdf.iloc[700:800]
subset
# Out:
#                              Rank                       Genre  \
# Title
# Funny Games                   701          Crime,Drama,Horror
# Ted                           702              Comedy,Fantasy
# RED                           703         Action,Comedy,Crime
# Australia                     704     Adventure,Drama,Romance
# Faster                        705          Action,Crime,Drama
# ...                           ...                         ...
# No Strings Attached           796              Comedy,Romance
# Rescue Dawn                   797   Adventure,Biography,Drama
# Despicable Me 2               798  Animation,Adventure,Comedy
# A Walk Among the Tombstones   799         Crime,Drama,Mystery
# The World's End               800        Action,Comedy,Sci-Fi
#
#                                                                    Description  \
# Title
# Funny Games                  Two psychopathic young men take a family hosta...
# ...

# %%
mdf
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
data=mdf[(mdf['Year']==2012)]
data
# Out:
#                             Rank                      Genre  \
# Title
# Prometheus                     2   Adventure,Mystery,Sci-Fi
# The Avengers                  77              Action,Sci-Fi
# The Dark Knight Rises        125            Action,Thriller
# The Place Beyond the Pines   136       Crime,Drama,Thriller
# Django Unchained             145              Drama,Western
# ...                          ...                        ...
# The Expendables 2            917  Action,Adventure,Thriller
# The Master                   930                      Drama
# End of Watch                 958       Crime,Drama,Thriller
# Rock of Ages                 973       Comedy,Drama,Musical
# Project X                    995                     Comedy
#
#                                                                   Description  \
# Title
# Prometheus                  Following clues to the origin of mankind, a te...
# ...

# %%
mdf['Year']
# Out:
# Title
# Guardians of the Galaxy    2014
# Prometheus                 2012
# Split                      2016
# Sing                       2016
# Suicide Squad              2016
#                            ...
# Secret in Their Eyes       2015
# Hostel: Part II            2007
# Step Up 2: The Streets     2008
# Search Party               2014
# Nine Lives                 2016
# Name: Year, Length: 1000, dtype: int64

# %%
data1=mdf[mdf['Director']=='Christopher Nolan']
data1
# Out:
#                        Rank                    Genre  \
# Title
# Interstellar             37   Adventure,Drama,Sci-Fi
# The Dark Knight          55       Action,Crime,Drama
# The Prestige             65     Drama,Mystery,Sci-Fi
# Inception                81  Action,Adventure,Sci-Fi
# The Dark Knight Rises   125          Action,Thriller
#
#                                                              Description  \
# Title
# Interstellar           A team of explorers travel through a wormhole ...
# The Dark Knight        When the menace known as the Joker wreaks havo...
# The Prestige           Two stage magicians engage in competitive one-...
# Inception              A thief, who steals corporate secrets through ...
# The Dark Knight Rises  Eight years after the Joker's reign of anarchy...
#
#                                 Director  \
# Title
# Interstellar           Christopher Nolan
# The Dark Knight        Christopher Nolan
# The Prestige           Christopher Nolan
# ...

# %%
#mdf[(mdf['Year']>=2012) & (mdf['Year']<=2016)].head
mdf[(mdf['Year']>=2012) & (mdf['Year']<=2016)]
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Selma                     990   Biography,Drama,History
# Project X                 995                    Comedy
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
mdf[(mdf['Year']>=2012) & (mdf['Year']<=2016)&(mdf['Rating']>=8)]
# Out:
#                                             Rank                       Genre  \
# Title
# Guardians of the Galaxy                        1     Action,Adventure,Sci-Fi
# La La Land                                     7          Comedy,Drama,Music
# Hacksaw Ridge                                 17     Biography,Drama,History
# Lion                                          19             Biography,Drama
# Arrival                                       20        Drama,Mystery,Sci-Fi
# Bahubali: The Beginning                       27      Action,Adventure,Drama
# Deadpool                                      34     Action,Adventure,Comedy
# Interstellar                                  37      Adventure,Drama,Sci-Fi
# Star Wars: Episode VII - The Force Awakens    51    Action,Adventure,Fantasy
# Mad Max: Fury Road                            68     Action,Adventure,Sci-Fi
# Zootopia                                      75  Animation,Adventure,Comedy
# ...

# %%
r=mdf['Revenue (Millions)']
r
# Out:
# Title
# Guardians of the Galaxy    333.13
# Prometheus                 126.46
# Split                      138.12
# Sing                       270.32
# Suicide Squad              325.02
#                             ...
# Secret in Their Eyes          NaN
# Hostel: Part II             17.54
# Step Up 2: The Streets      58.01
# Search Party                  NaN
# Nine Lives                  19.64
# Name: Revenue (Millions), Length: 1000, dtype: float64

# %%
r.describe()
# Out:
# count    872.000000
# mean      82.956376
# std      103.253540
# min        0.000000
# 25%       13.270000
# 50%       47.985000
# 75%      113.715000
# max      936.630000
# Name: Revenue (Millions), dtype: float64

# %%
mdf[(mdf['Year']>=2005) & (mdf['Year']<=2010)&(mdf['Rating']<=8.0)]
# Out:
#                                             Rank                     Genre  \
# Title
# 5- 25- 77                                     40              Comedy,Drama
# Pirates of the Caribbean: At World's End      76  Action,Adventure,Fantasy
# Pirates of the Caribbean: Dead Man's Chest    79  Action,Adventure,Fantasy
# Avatar                                        88  Action,Adventure,Fantasy
# 300                                          114        Action,Fantasy,War
# ...                                          ...                       ...
# Martyrs                                      989                    Horror
# Underworld: Rise of the Lycans               991  Action,Adventure,Fantasy
# Resident Evil: Afterlife                     994   Action,Adventure,Horror
# Hostel: Part II                              997                    Horror
# Step Up 2: The Streets                       998       Drama,Music,Romance
#
# ...

# %%
r.quantile()
# Out:
# 47.985

# %%
mdf[(mdf['Year']>=2005) & (mdf['Year']<=2010)&(mdf['Rating']<=8.0)|]
